# %%
from bs4 import BeautifulSoup
from datetime import datetime
import requests
import os
import unicodedata, re
import pandas as pd

# global vars
protocol_dir= './data/bundestagsprotokolle'
parties = ['GRÜNE', 'LINKE', 'FDP', 'CDU/CSU', 'SPD', 'AfD']
interaction_types = {'applause': 'Beifall', 'shout': 'Zurufe'}

# %%
def download_parlament_protocols(protocol_dir: str):
    os.makedirs(protocol_dir, exist_ok=True)
    root_url = "https://www.bundestag.de"
    url = "https://www.bundestag.de/ajax/filterlist/de/services/opendata/866354-866354?offset="
    
    for offset in range(0,500,10):
        print(f"Current offset {offset}")
        protocol_list = requests.get(url + f"{offset}").text
        soup = BeautifulSoup(protocol_list, 'html.parser')

        tags = soup.find_all('a')
        if not tags:
            print(f'Break at offset {offset}')
            break

        for link in tags:
            if link.get('href', '').endswith('.xml'):
                xml_protocol = requests.get(root_url + link.get('href')).text
                xml_soup = BeautifulSoup(xml_protocol, 'lxml') # to extract protocol date
                german_date = datetime.strptime(xml_soup.find("datum").get("date"), '%d.%m.%Y')
                open(os.path.join(protocol_dir, f'{german_date.strftime("%Y-%m-%d")}-protocol.xml'), 'w', encoding='utf-8').write(xml_protocol)

# %%
def nrmlz(s):
    return unicodedata.normalize("NFKD",s)

def get_party_interactions(speech) -> dict:
    interactions = {f"{interaction_type}_{party}":0 for interaction_type in interaction_types for party in parties}
    for comment in speech.find_all('kommentar'):
        for interaction_type in interaction_types:
            if interaction_types[interaction_type] in comment.text:
                interaction_per_party = {party : len(re.findall(party, comment.text)) for party in parties}
                
                for party in parties:
                        interactions[f"{interaction_type}_" + party] += interaction_per_party[party]
                    
    return interactions

def load_all_speeches() -> list:
    speeches = []
    for protocol in os.listdir(protocol_dir):
        print(f"Current protcol: {protocol}")
        soup = BeautifulSoup(open(f'{protocol_dir}/{protocol}', 'r', encoding='utf-8').read(), 'xml')
        rede = soup.find('rede')
        date = datetime.strptime(protocol.split('-protocol.xml')[0], '%Y-%m-%d')
        for speech in soup.find_all('rede'):
            speech_text = nrmlz(" ".join([x.getText() for x in rede.find_all('p', {'klasse':'J'})])) 
            speaker = speech.find('redner')
            speeches.append({
                'speaker': f"{speaker.find('vorname').text} {speaker.find('nachname').text}",
                'party': speaker.find('fraktion').text if speaker.find('fraktion') else speaker.find("rolle").text if speaker.find("rolle") else None,
                'speech': speech_text,
                'date': date,
                **get_party_interactions(speech)
            })
            
    return speeches

# %%
if not os.path.exists(protocol_dir) or len(os.listdir(protocol_dir)) == 0:
    download_parlament_protocols(protocol_dir)
    
if os.path.exists(protocol_dir) and len(os.listdir(protocol_dir)) > 0:
    speeches = load_all_speeches()
# Out:
# Current protcol: 2021-10-26-protocol.xml
# Current protcol: 2021-11-11-protocol.xml
# Current protcol: 2021-11-18-protocol.xml
# Current protcol: 2021-12-07-protocol.xml
# Current protcol: 2021-12-08-protocol.xml
# Current protcol: 2021-12-09-protocol.xml
# Current protcol: 2021-12-10-protocol.xml
# Current protcol: 2021-12-15-protocol.xml
# Current protcol: 2021-12-16-protocol.xml
# Current protcol: 2022-01-12-protocol.xml
# Current protcol: 2022-01-13-protocol.xml
# Current protcol: 2022-01-14-protocol.xml
# Current protcol: 2022-01-26-protocol.xml
# Current protcol: 2022-01-27-protocol.xml
# Current protcol: 2022-01-28-protocol.xml
# Current protcol: 2022-02-16-protocol.xml
# Current protcol: 2022-02-17-protocol.xml
# Current protcol: 2022-02-18-protocol.xml
# Current protcol: 2022-02-27-protocol.xml
# Current protcol: 2022-03-16-protocol.xml
# Current protcol: 2022-03-17-protocol.xml
# Current protcol: 2022-03-18-protocol.xml
# Current protcol: 2022-03-22-protocol.xml
# Current protcol: 2022-03-23-protocol.xml
# Current protcol: 2022-03-24-protocol.xml
# Current protcol: 2022-03-25-protocol.xml
# Current protcol: 2022-04-06-protocol.xml
# Current protcol: 2022-04-07-protocol.xml
# Current protcol: 2022-04-08-protocol.xml
# Current protcol: 2022-04-27-protocol.xml
# Current protcol: 2022-04-28-protocol.xml
# Current protcol: 2022-04-29-protocol.xml
# Current protcol: 2022-05-08-protocol.xml
# Current protcol: 2022-05-11-protocol.xml
# Current protcol: 2022-05-12-protocol.xml
# Current protcol: 2022-05-13-protocol.xml
# Current protcol: 2022-05-19-protocol.xml
# Current protcol: 2022-05-20-protocol.xml
# Current protcol: 2022-05-31-protocol.xml
# Current protcol: 2022-06-01-protocol.xml
# Current protcol: 2022-06-02-protocol.xml
# Current protcol: 2022-06-03-protocol.xml
# Current protcol: 2022-06-22-protocol.xml
# Current protcol: 2022-06-23-protocol.xml
# Current protcol: 2022-06-24-protocol.xml
# Current protcol: 2022-07-06-protocol.xml
# Current protcol: 2022-07-07-protocol.xml
# Current protcol: 2022-07-08-protocol.xml
# Current protcol: 2022-09-06-protocol.xml
# Current protcol: 2022-09-07-protocol.xml
# Current protcol: 2022-09-08-protocol.xml
# Current protcol: 2022-09-09-protocol.xml
# Current protcol: 2022-09-21-protocol.xml
# Current protcol: 2022-09-22-protocol.xml
# Current protcol: 2022-09-23-protocol.xml
# Current protcol: 2022-09-28-protocol.xml
# Current protcol: 2022-09-29-protocol.xml
# Current protcol: 2022-09-30-protocol.xml
# Current protcol: 2022-10-12-protocol.xml
# Current protcol: 2022-10-13-protocol.xml
# Current protcol: 2022-10-14-protocol.xml
# Current protcol: 2022-10-19-protocol.xml
# Current protcol: 2022-10-20-protocol.xml
# Current protcol: 2022-10-21-protocol.xml
# Current protcol: 2022-11-09-protocol.xml
# Current protcol: 2022-11-10-protocol.xml
# Current protcol: 2022-11-11-protocol.xml
# Current protcol: 2022-11-21-protocol.xml
# Current protcol: 2022-11-23-protocol.xml
# Current protcol: 2022-11-24-protocol.xml
# Current protcol: 2022-11-25-protocol.xml
# Current protcol: 2022-11-30-protocol.xml
# Current protcol: 2022-12-01-protocol.xml
# Current protcol: 2022-12-02-protocol.xml
# Current protcol: 2022-12-14-protocol.xml
# Current protcol: 2022-12-15-protocol.xml
# Current protcol: 2022-12-16-protocol.xml
# Current protcol: 2023-01-18-protocol.xml
# Current protcol: 2023-01-19-protocol.xml
# Current protcol: 2023-01-20-protocol.xml
# Current protcol: 2023-01-25-protocol.xml
# Current protcol: 2023-01-26-protocol.xml
# Current protcol: 2023-01-27-protocol.xml
# Current protcol: 2023-02-08-protocol.xml
# Current protcol: 2023-02-09-protocol.xml
# Current protcol: 2023-02-10-protocol.xml
# Current protcol: 2023-03-01-protocol.xml
# Current protcol: 2023-03-02-protocol.xml
# Current protcol: 2023-03-03-protocol.xml
# Current protcol: 2023-03-15-protocol.xml
# Current protcol: 2023-03-16-protocol.xml
# Current protcol: 2023-03-17-protocol.xml
# Current protcol: 2023-03-29-protocol.xml
# Current protcol: 2023-03-30-protocol.xml
# Current protcol: 2023-03-31-protocol.xml
# Current protcol: 2023-04-19-protocol.xml
# Current protcol: 2023-04-20-protocol.xml
# Current protcol: 2023-04-21-protocol.xml
# Current protcol: 2023-04-26-protocol.xml
# Current protcol: 2023-04-27-protocol.xml
# Current protcol: 2023-04-28-protocol.xml
# Current protcol: 2023-05-10-protocol.xml
# Current protcol: 2023-05-11-protocol.xml
# Current protcol: 2023-05-12-protocol.xml
# Current protcol: 2023-05-24-protocol.xml
# Current protcol: 2023-05-25-protocol.xml
# Current protcol: 2023-05-26-protocol.xml
# Current protcol: 2023-06-14-protocol.xml
# Current protcol: 2023-06-15-protocol.xml
# Current protcol: 2023-06-16-protocol.xml
# Current protcol: 2023-06-21-protocol.xml
# Current protcol: 2023-06-22-protocol.xml
# Current protcol: 2023-06-23-protocol.xml
# Current protcol: 2023-07-05-protocol.xml
# Current protcol: 2023-07-06-protocol.xml
# Current protcol: 2023-07-07-protocol.xml
# Current protcol: 2023-09-05-protocol.xml
# Current protcol: 2023-09-06-protocol.xml
# Current protcol: 2023-09-07-protocol.xml
# Current protcol: 2023-09-08-protocol.xml
# Current protcol: 2023-09-20-protocol.xml
# Current protcol: 2023-09-21-protocol.xml
# Current protcol: 2023-09-22-protocol.xml
# Current protcol: 2023-09-27-protocol.xml
# Current protcol: 2023-09-28-protocol.xml
# Current protcol: 2023-09-29-protocol.xml
# Current protcol: 2023-10-11-protocol.xml
# Current protcol: 2023-10-12-protocol.xml
# Current protcol: 2023-10-13-protocol.xml
# Current protcol: 2023-10-18-protocol.xml
# Current protcol: 2023-10-19-protocol.xml
# Current protcol: 2023-10-20-protocol.xml
# Current protcol: 2023-11-08-protocol.xml
# Current protcol: 2023-11-09-protocol.xml
# Current protcol: 2023-11-10-protocol.xml
# Current protcol: 2023-11-15-protocol.xml
# Current protcol: 2023-11-16-protocol.xml
# Current protcol: 2023-11-17-protocol.xml
# Current protcol: 2023-11-28-protocol.xml
# Current protcol: 2023-11-29-protocol.xml
# Current protcol: 2023-11-30-protocol.xml
# Current protcol: 2023-12-01-protocol.xml
# Current protcol: 2023-12-13-protocol.xml
# Current protcol: 2023-12-14-protocol.xml
# Current protcol: 2023-12-15-protocol.xml
# Current protcol: 2024-01-17-protocol.xml
# Current protcol: 2024-01-18-protocol.xml
# Current protcol: 2024-01-19-protocol.xml
# Current protcol: 2024-01-30-protocol.xml
# Current protcol: 2024-01-31-protocol.xml
# Current protcol: 2024-02-01-protocol.xml
# Current protcol: 2024-02-02-protocol.xml
# Current protcol: 2024-02-21-protocol.xml
# Current protcol: 2024-02-22-protocol.xml
# Current protcol: 2024-02-23-protocol.xml
# Current protcol: 2024-03-13-protocol.xml
# Current protcol: 2024-03-14-protocol.xml
# Current protcol: 2024-03-15-protocol.xml
# Current protcol: 2024-03-20-protocol.xml
# Current protcol: 2024-03-21-protocol.xml
# Current protcol: 2024-03-22-protocol.xml
# Current protcol: 2024-04-10-protocol.xml
# Current protcol: 2024-04-11-protocol.xml
# Current protcol: 2024-04-12-protocol.xml
# Current protcol: 2024-04-24-protocol.xml
# Current protcol: 2024-04-25-protocol.xml
# Current protcol: 2024-04-26-protocol.xml
# Current protcol: 2024-05-15-protocol.xml
# Current protcol: 2024-05-16-protocol.xml
# Current protcol: 2024-05-17-protocol.xml
# Current protcol: 2024-06-05-protocol.xml
# Current protcol: 2024-06-06-protocol.xml
# Current protcol: 2024-06-07-protocol.xml
# Current protcol: 2024-06-12-protocol.xml
# Current protcol: 2024-06-13-protocol.xml
# Current protcol: 2024-06-14-protocol.xml

# %%
df = pd.DataFrame(speeches)
df.columns = df.columns.str.lower()
df.to_csv('./data/all_bundestagsprotokolle.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22214 entries, 0 to 22213
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   speaker           22214 non-null  object
#  1   party             22213 non-null  object
#  2   speech            22214 non-null  object
#  3   date              22214 non-null  datetime64[ns]
#  4   applause_grüne    22214 non-null  int64
#  5   applause_linke    22214 non-null  int64
#  6   applause_fdp      22214 non-null  int64
#  7   applause_cdu/csu  22214 non-null  int64
#  8   applause_spd      22214 non-null  int64
#  9   applause_afd      22214 non-null  int64
#  10  shout_grüne       22214 non-null  int64
#  11  shout_linke       22214 non-null  int64
#  12  shout_fdp         22214 non-null  int64
#  13  shout_cdu/csu     22214 non-null  int64
#  14  shout_spd         22214 non-null  int64
#  15  shout_afd         22214 non-null  int64
# dtypes: datetime64[ns](1), int64(12), object(3)
# memory usage: 2.7+ MB
